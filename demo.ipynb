# %%
import numpy as np
import cv2

map = cv2.imread("map.png", 0) # 0 for greyscale, single-channel
HEIGHT, WIDTH = map.shape

print(map)
# Blur map
# map = cv2.GaussianBlur(map, (7,7), 0) # Kernel needs odd dimensions (11,11)

rx, ry, rtheta = (WIDTH/4, HEIGHT/4, 0)

################

STEP = 5
TURN = np.radians(25)

def get_input():
    fwd = 0
    turn = 0
    halt = False
    k = cv2.waitKey(0)
    if k == 82: # Up arrow
        fwd = STEP
    elif k == 83: # Right arrow
        turn = TURN
    elif k == 81: # Left arrow
        turn = -TURN
    else:
        halt = True
    return fwd, turn, halt

################

SIGMA_STEP = 0.5
SIGMA_TURN = np.radians(5) # best way to control trackability for demo

def move_robot(rx, ry, rtheta, fwd, turn):
    # Re-orient and step robot, with noise
    fwd_noisy = fwd + np.random.normal(0.0, SIGMA_STEP, 1)
    rx += fwd_noisy * np.cos(rtheta)
    ry += fwd_noisy * np.sin(rtheta)
    print("fwd_noisy=", fwd_noisy)

    turn_noisy = turn + np.random.normal(0.0, SIGMA_TURN, 1)
    rtheta += turn_noisy
    print("turn_noisy=", np.degrees(turn_noisy))

    return rx, ry, rtheta

################

NUM_PARTICLES = 3000

def init():
    particles = np.random.rand(NUM_PARTICLES, 3)
    particles *= np.array( (WIDTH, HEIGHT, np.radians(360)) )
    return particles

#################

def move_particles(particles, fwd, turn):
    particles[:,0] += fwd * np.cos(particles[:,2])
    particles[:,1] += fwd * np.sin(particles[:,2])
    particles[:,2] += turn

    particles[:,0] = np.clip(particles[:,0], 0.0, WIDTH-1)
    particles[:,1] = np.clip(particles[:,1], 0.0, HEIGHT-1)
    return particles

################

def sense(x, y, noisy=False):
    SIGMA_SENSOR = 5
    x = int(x)
    y = int(y)
    if noisy:
        return map[y,x] + np.random.normal(0.0, SIGMA_SENSOR, 1)
    return map[y,x]

###############

def sense(x, y, noisy=False):
    SIGMA_SENSOR = 5
    x = int(x)
    y = int(y)
    if noisy:
        return map[y,x] + np.random.normal(0.0, SIGMA_SENSOR, 1)
    return map[y,x]

###############

def compute_weights(particles, robot_sensor):
    errors = np.zeros(NUM_PARTICLES)
    for i in range(NUM_PARTICLES):
        particle_sensor = sense(particles[i,0], particles[i,1])
        errors[i] = abs(robot_sensor - particle_sensor)
    weights = np.max(errors) - errors

    # Kill off particles on edge
    weights[
        (particles[:,0] == 0) |
        (particles[:,0] == WIDTH-1) |
        (particles[:,1] == 0) |
        (particles[:,1] == HEIGHT-1)
    ] = 0.0

    # Increase sensitivity
    weights = weights ** 3
    return weights

###############


def resample(particles, weights):
    probabilities = weights / np.sum(weights)
    new_index = np.random.choice(
        NUM_PARTICLES,
        size=NUM_PARTICLES,
        p=probabilities
    )
    particles = particles[new_index,:]
    return particles

############

def add_noise(particles):
    SIGMA_PARTICLE_STEP = 2 #2
    SIGMA_PARTICLE_TURN = np.pi / 24 #np.pi / 24
    noise = np.concatenate((
        np.random.normal(0, SIGMA_PARTICLE_STEP, (NUM_PARTICLES,1)),
        np.random.normal(0, SIGMA_PARTICLE_STEP, (NUM_PARTICLES,1)),
        np.random.normal(0, SIGMA_PARTICLE_TURN, (NUM_PARTICLES,1)),
        ),
        axis=1
    )
    particles += noise
    return particles

############

def display(map, rx, ry, particles):
    lmap = cv2.cvtColor(map, cv2.COLOR_GRAY2BGR)

    # Display particles
    if len(particles) > 0 and False:
        for i in range(NUM_PARTICLES):
            cv2.circle(lmap,
                       (int(particles[i,0]), int(particles[i,1])),
                       1,
                       (255,0,0),
                       1)

    # Display robot
    cv2.circle(lmap, (int(rx), int(ry)), 5, (0,255,0), 10)

    # Display best guess
    if len(particles) > 0:
        px = np.mean(particles[:,0])
        py = np.mean(particles[:,1])
        cv2.circle(lmap, (int(px), int(py)), 5, (0,0,255), 5)

    cv2.imshow('map', lmap)

#################

particles = init()
while True:
    display(map, rx, ry, particles)
    fwd, turn, halt = get_input()
    if halt:
        break
    rx, ry, rtheta = move_robot(rx, ry, rtheta, fwd, turn)
    particles = move_particles(particles, fwd, turn)
    if fwd != 0:
        robot_sensor = sense(rx, ry, noisy=True)
        weights = compute_weights(particles, robot_sensor)
        particles = resample(particles, weights)
        particles = add_noise(particles)

cv2.destroyAllWindows()
# Out:
# [[ 79  80  82 ... 133 148 156]
#  [ 78  79  81 ... 138 156 164]
#  [ 76  77  79 ... 147 170 180]
#  ...
#  [181 181 182 ... 174 172 171]
#  [178 178 178 ... 180 179 178]
#  [177 177 177 ... 183 182 182]]
# fwd_noisy= [4.54369459]
# turn_noisy= [-7.68406068]
# fwd_noisy= [5.38422432]
# turn_noisy= [-1.03005736]
# fwd_noisy= [5.66663014]
# turn_noisy= [-3.87830852]
# fwd_noisy= [5.59899192]
# turn_noisy= [9.87598752]
# fwd_noisy= [5.46976337]
# turn_noisy= [-0.94521715]
# fwd_noisy= [4.44267452]
# turn_noisy= [3.18617132]
# fwd_noisy= [0.17897423]
# turn_noisy= [-26.44705218]
# fwd_noisy= [0.05089468]
# turn_noisy= [-20.33416616]
# fwd_noisy= [0.3455879]
# turn_noisy= [-29.19428858]
# fwd_noisy= [5.22435232]
# turn_noisy= [4.54898885]
# fwd_noisy= [5.7151412]
# turn_noisy= [2.83848834]
# fwd_noisy= [4.41879171]
# turn_noisy= [0.69692063]
# fwd_noisy= [5.60008541]
# turn_noisy= [-7.73253263]
# fwd_noisy= [4.77837278]
# turn_noisy= [3.15162428]
# fwd_noisy= [5.92610551]
# turn_noisy= [7.75565692]
# fwd_noisy= [4.97696091]
# turn_noisy= [1.48940809]
# fwd_noisy= [4.97151869]
# turn_noisy= [-4.6299124]
# fwd_noisy= [4.99461073]
# turn_noisy= [8.14229802]
# fwd_noisy= [4.51503938]
# turn_noisy= [3.85009818]
# fwd_noisy= [4.72877532]
# turn_noisy= [3.35496942]
# fwd_noisy= [5.52699185]
# turn_noisy= [1.29535191]
# fwd_noisy= [5.02728025]
# turn_noisy= [-3.56522439]
# fwd_noisy= [4.5535048]
# turn_noisy= [0.38082215]
# fwd_noisy= [4.88982246]
# turn_noisy= [-3.2528623]
# fwd_noisy= [4.382273]
# turn_noisy= [0.89409804]
# fwd_noisy= [5.42973248]
# turn_noisy= [6.71536187]
# fwd_noisy= [5.8935252]
# turn_noisy= [4.35851492]
# fwd_noisy= [4.66568411]
# turn_noisy= [-0.85367144]
# fwd_noisy= [5.63234758]
# turn_noisy= [14.62483366]
# fwd_noisy= [5.48476271]
# turn_noisy= [6.62038734]
# fwd_noisy= [5.1240011]
# turn_noisy= [6.62054429]
# fwd_noisy= [5.84925893]
# turn_noisy= [0.34641885]
# fwd_noisy= [4.49832347]
# turn_noisy= [-6.74313812]
# fwd_noisy= [5.53631653]
# turn_noisy= [-2.57511824]
# fwd_noisy= [4.46813946]
# turn_noisy= [-2.42888418]
# fwd_noisy= [4.2113996]
# turn_noisy= [1.56779311]
# fwd_noisy= [4.62343276]
# turn_noisy= [-6.1410828]
# fwd_noisy= [5.81726915]
# turn_noisy= [-1.75598128]
# fwd_noisy= [4.62516515]
# turn_noisy= [0.29553959]
# fwd_noisy= [-0.19601072]
# turn_noisy= [25.03449742]
# fwd_noisy= [0.71349301]
# turn_noisy= [31.6012304]
# fwd_noisy= [-0.22143748]
# turn_noisy= [19.51623801]
# fwd_noisy= [-0.18320367]
# turn_noisy= [23.1236913]
# fwd_noisy= [5.37011884]
# turn_noisy= [-2.62593404]
# fwd_noisy= [4.78811965]
# turn_noisy= [2.8232895]
# fwd_noisy= [5.1780655]
# turn_noisy= [-8.08606421]
# fwd_noisy= [4.19935244]
# turn_noisy= [0.5831093]
# fwd_noisy= [3.96620994]
# turn_noisy= [-2.21455522]
# fwd_noisy= [4.99620652]
# turn_noisy= [2.02738323]
# fwd_noisy= [4.36318668]
# turn_noisy= [2.18812453]
# fwd_noisy= [5.36993037]
# turn_noisy= [-7.46152995]
# fwd_noisy= [5.20210112]
# turn_noisy= [-4.03953156]
# fwd_noisy= [5.63124798]
# turn_noisy= [-12.35712981]
# fwd_noisy= [4.52118317]
# turn_noisy= [3.28896139]
# fwd_noisy= [5.66556406]
# turn_noisy= [13.19811631]
# fwd_noisy= [5.08070031]
# turn_noisy= [0.53971036]
# fwd_noisy= [4.78260323]
# turn_noisy= [7.2580928]
# fwd_noisy= [4.74355715]
# turn_noisy= [4.40321793]
# fwd_noisy= [5.24398308]
# turn_noisy= [-4.09898786]
# fwd_noisy= [5.10355245]
# turn_noisy= [7.39217564]
# fwd_noisy= [5.25253557]
# turn_noisy= [6.03063278]
# fwd_noisy= [5.30049246]
# turn_noisy= [-3.07772059]
# fwd_noisy= [4.9939365]
# turn_noisy= [-6.44486767]
# fwd_noisy= [4.27702765]
# turn_noisy= [-5.59372565]
# fwd_noisy= [5.61157189]
# turn_noisy= [5.00006237]
# fwd_noisy= [5.56573077]
# turn_noisy= [-1.19384051]
# fwd_noisy= [6.59749161]
# turn_noisy= [5.36111898]
# fwd_noisy= [5.27103578]
# turn_noisy= [5.42313448]
# fwd_noisy= [4.75946899]
# turn_noisy= [4.18615322]
# fwd_noisy= [5.35848076]
# turn_noisy= [-3.48747538]
# fwd_noisy= [5.31381151]
# turn_noisy= [-9.73567146]
# fwd_noisy= [4.08485471]
# turn_noisy= [-1.66231518]
# fwd_noisy= [5.64427147]
# turn_noisy= [-1.39553223]
# fwd_noisy= [5.88616472]
# turn_noisy= [-6.5352672]
# fwd_noisy= [4.44526505]
# turn_noisy= [-4.04055514]
# fwd_noisy= [5.25935258]
# turn_noisy= [8.21957805]
# fwd_noisy= [5.37748685]
# turn_noisy= [-0.85025081]
# fwd_noisy= [4.73199463]
# turn_noisy= [-6.74420029]
# fwd_noisy= [4.35223532]
# turn_noisy= [-4.27396877]
# fwd_noisy= [-0.4138994]
# turn_noisy= [24.90421304]
# fwd_noisy= [0.25328494]
# turn_noisy= [23.28586021]
# fwd_noisy= [0.86160978]
# turn_noisy= [27.1483317]
# fwd_noisy= [5.41389658]
# turn_noisy= [-3.8197897]
# fwd_noisy= [4.72426988]
# turn_noisy= [-6.44882436]
# fwd_noisy= [3.55507186]
# turn_noisy= [10.63963586]
# fwd_noisy= [4.59096431]
# turn_noisy= [0.00603383]
# fwd_noisy= [5.48741232]
# turn_noisy= [-2.06218015]
# fwd_noisy= [4.89556538]
# turn_noisy= [0.43906867]
# fwd_noisy= [4.53188111]
# turn_noisy= [3.53234097]
# fwd_noisy= [4.84809569]
# turn_noisy= [-0.64057548]
# fwd_noisy= [4.68429784]
# turn_noisy= [4.05225059]
# fwd_noisy= [4.92074966]
# turn_noisy= [-8.90916407]
# fwd_noisy= [5.18474215]
# turn_noisy= [6.75180254]
# fwd_noisy= [4.99265958]
# turn_noisy= [-0.84009841]
# fwd_noisy= [4.50854224]
# turn_noisy= [6.34049609]
# fwd_noisy= [4.57816287]
# turn_noisy= [2.65899648]
# fwd_noisy= [4.63644411]
# turn_noisy= [-0.0345917]
# fwd_noisy= [5.95765771]
# turn_noisy= [1.62032911]
# fwd_noisy= [5.88177275]
# turn_noisy= [-11.77999533]
# fwd_noisy= [4.74751605]
# turn_noisy= [-0.67689991]
# fwd_noisy= [4.72420738]
# turn_noisy= [6.1096579]
# fwd_noisy= [4.86395717]
# turn_noisy= [2.87231204]
# fwd_noisy= [4.56683364]
# turn_noisy= [-0.4689846]
# fwd_noisy= [5.93421818]
# turn_noisy= [4.40047162]
# fwd_noisy= [5.10161855]
# turn_noisy= [-0.43972882]
# fwd_noisy= [5.25244548]
# turn_noisy= [-5.31297306]
# fwd_noisy= [4.60559405]
# turn_noisy= [1.91105509]
# fwd_noisy= [4.44960936]
# turn_noisy= [-3.42744559]
# fwd_noisy= [5.47327246]
# turn_noisy= [-0.08730303]
# fwd_noisy= [4.54782257]
# turn_noisy= [-3.36498073]
# fwd_noisy= [4.5422803]
# turn_noisy= [-4.90995941]
# fwd_noisy= [4.76214422]
# turn_noisy= [-3.49447147]
# fwd_noisy= [5.36493985]
# turn_noisy= [3.12611918]
# fwd_noisy= [5.02707141]
# turn_noisy= [5.49227681]
# fwd_noisy= [5.49330953]
# turn_noisy= [4.42518619]
# fwd_noisy= [5.12249784]
# turn_noisy= [11.32923056]
# fwd_noisy= [4.48634954]
# turn_noisy= [-1.28302822]
# fwd_noisy= [4.82251643]
# turn_noisy= [9.86858754]
# fwd_noisy= [5.00526485]
# turn_noisy= [2.34984623]
# fwd_noisy= [4.9958419]
# turn_noisy= [-6.58965865]
# fwd_noisy= [5.36792016]
# turn_noisy= [-0.67797179]
# fwd_noisy= [5.08542559]
# turn_noisy= [1.480977]
# fwd_noisy= [5.72320512]
# turn_noisy= [2.39783998]
# fwd_noisy= [5.39272991]
# turn_noisy= [-3.44860913]
# fwd_noisy= [4.40057231]
# turn_noisy= [4.09152211]
# fwd_noisy= [5.37939431]
# turn_noisy= [-0.30712275]
# fwd_noisy= [5.98828119]
# turn_noisy= [-14.36582948]
# fwd_noisy= [5.4990777]
# turn_noisy= [-9.98857811]
# fwd_noisy= [4.61312879]
# turn_noisy= [7.65172427]
# fwd_noisy= [4.23851092]
# turn_noisy= [-2.89160284]
# fwd_noisy= [5.6530779]
# turn_noisy= [-9.34671435]
# fwd_noisy= [4.74331052]
# turn_noisy= [1.7501321]
# fwd_noisy= [4.56044867]
# turn_noisy= [-1.46364212]
# fwd_noisy= [0.67388953]
# turn_noisy= [29.32403251]
# fwd_noisy= [-0.81915403]
# turn_noisy= [24.82715979]
# fwd_noisy= [0.68851137]
# turn_noisy= [18.38743101]
# fwd_noisy= [-0.23964345]
# turn_noisy= [27.16491253]
# fwd_noisy= [5.12160973]
# turn_noisy= [0.77818627]
# fwd_noisy= [6.41499613]
# turn_noisy= [-3.23945168]
# fwd_noisy= [5.00007546]
# turn_noisy= [3.97411848]
# fwd_noisy= [5.11856784]
# turn_noisy= [0.00722357]
# fwd_noisy= [5.18649647]
# turn_noisy= [0.52981298]
# fwd_noisy= [4.9297292]
# turn_noisy= [-1.26865658]
# fwd_noisy= [5.61366821]
# turn_noisy= [-3.56909194]
# fwd_noisy= [4.51169765]
# turn_noisy= [3.70681793]
# fwd_noisy= [5.41914215]
# turn_noisy= [0.72139439]
# fwd_noisy= [5.62715823]
# turn_noisy= [-0.01945191]
# fwd_noisy= [5.69359939]
# turn_noisy= [-5.5802358]
# fwd_noisy= [5.7190276]
# turn_noisy= [7.94849293]
# fwd_noisy= [4.87399005]
# turn_noisy= [6.05964032]
# fwd_noisy= [5.12476469]
# turn_noisy= [-3.64413361]
# fwd_noisy= [4.16507707]
# turn_noisy= [-2.5826935]
# fwd_noisy= [4.94424755]
# turn_noisy= [-10.04138338]
# fwd_noisy= [4.53386013]
# turn_noisy= [-2.97072191]
# fwd_noisy= [5.91114759]
# turn_noisy= [-1.39301518]
# fwd_noisy= [5.47010646]
# turn_noisy= [2.12582246]
# fwd_noisy= [5.38841696]
# turn_noisy= [6.10193906]
# fwd_noisy= [4.58082]
# turn_noisy= [-10.14937894]
# fwd_noisy= [5.39028215]
# turn_noisy= [-2.73854372]
# fwd_noisy= [5.884876]
# turn_noisy= [2.84233127]
# fwd_noisy= [4.85464562]
# turn_noisy= [7.97067956]
# fwd_noisy= [4.1578744]
# turn_noisy= [4.09465072]
# fwd_noisy= [-1.10395036]
# turn_noisy= [27.50370149]
# fwd_noisy= [-0.09437441]
# turn_noisy= [24.04628786]
# fwd_noisy= [-0.2063294]
# turn_noisy= [23.85100484]
# fwd_noisy= [-0.52606427]
# turn_noisy= [28.51950028]
# fwd_noisy= [4.9644904]
# turn_noisy= [4.1301158]
# fwd_noisy= [4.91974146]
# turn_noisy= [-3.44784442]
# fwd_noisy= [4.3276981]
# turn_noisy= [-9.0241286]
# fwd_noisy= [4.79952278]
# turn_noisy= [1.97158063]
# fwd_noisy= [5.6538195]
# turn_noisy= [8.83627835]
# fwd_noisy= [5.11888533]
# turn_noisy= [-4.88543936]
# fwd_noisy= [5.17999538]
# turn_noisy= [5.85820918]
# fwd_noisy= [5.00855736]
# turn_noisy= [5.71777466]
# fwd_noisy= [4.12940039]
# turn_noisy= [-3.95961439]
# fwd_noisy= [4.78805359]
# turn_noisy= [-2.22235026]
# fwd_noisy= [4.89927347]
# turn_noisy= [-6.64037656]
# fwd_noisy= [4.64137987]
# turn_noisy= [-5.66609098]
# fwd_noisy= [5.14072699]
# turn_noisy= [-4.79574321]
# fwd_noisy= [5.73906652]
# turn_noisy= [2.119987]
# fwd_noisy= [4.61515065]
# turn_noisy= [0.64094851]
# fwd_noisy= [5.37826409]
# turn_noisy= [-4.81168794]
# fwd_noisy= [5.12942414]
# turn_noisy= [-4.97333907]
# fwd_noisy= [4.56103927]
# turn_noisy= [4.7864834]
# fwd_noisy= [5.32244585]
# turn_noisy= [3.52040383]
# fwd_noisy= [5.33493439]
# turn_noisy= [-2.19880036]
# fwd_noisy= [4.91289122]
# turn_noisy= [1.62797972]
# fwd_noisy= [4.47275438]
# turn_noisy= [-0.6304102]
# fwd_noisy= [4.15296835]
# turn_noisy= [-3.24338461]
# fwd_noisy= [4.67419449]
# turn_noisy= [-3.05500908]
# fwd_noisy= [5.81056946]
# turn_noisy= [-1.27200495]
# fwd_noisy= [4.93310302]
# turn_noisy= [4.6374759]
# fwd_noisy= [5.09637271]
# turn_noisy= [-2.04999007]
# fwd_noisy= [4.81053877]
# turn_noisy= [0.46607117]
# fwd_noisy= [5.77870017]
# turn_noisy= [7.86408786]
# fwd_noisy= [4.76781735]
# turn_noisy= [1.87518207]
# fwd_noisy= [4.71478493]
# turn_noisy= [2.70453392]
# fwd_noisy= [4.91271032]
# turn_noisy= [4.6854962]
# fwd_noisy= [4.49661045]
# turn_noisy= [3.92513966]
# fwd_noisy= [5.07055057]
# turn_noisy= [4.09967549]
# fwd_noisy= [4.85334497]
# turn_noisy= [-7.78181649]
# fwd_noisy= [4.99491469]
# turn_noisy= [7.82868209]
# fwd_noisy= [4.05403979]
# turn_noisy= [0.71194864]
# fwd_noisy= [4.92910897]
# turn_noisy= [0.45515355]
# fwd_noisy= [4.04923892]
# turn_noisy= [1.83180417]
# fwd_noisy= [4.53413164]
# turn_noisy= [-4.16347806]
# fwd_noisy= [5.24330216]
# turn_noisy= [1.88768007]
# fwd_noisy= [4.57895084]
# turn_noisy= [2.60240522]
# fwd_noisy= [5.08833206]
# turn_noisy= [-7.93289627]
# fwd_noisy= [-0.32654819]
# turn_noisy= [-26.35054507]
# fwd_noisy= [0.58904089]
# turn_noisy= [-19.80315472]
# fwd_noisy= [-0.3347476]
# turn_noisy= [-26.11435286]
# fwd_noisy= [5.158931]
# turn_noisy= [-10.01112412]
# fwd_noisy= [4.95273391]
# turn_noisy= [6.36019447]
# fwd_noisy= [4.6365058]
# turn_noisy= [3.33616049]
# fwd_noisy= [5.53210575]
# turn_noisy= [7.64401365]
# fwd_noisy= [5.10892279]
# turn_noisy= [-1.72918811]
# fwd_noisy= [4.52655423]
# turn_noisy= [1.76379925]
# fwd_noisy= [4.72733252]
# turn_noisy= [0.37515684]
# fwd_noisy= [4.3092993]
# turn_noisy= [0.92477243]
# fwd_noisy= [5.74404865]
# turn_noisy= [5.56273683]
# fwd_noisy= [5.05633075]
# turn_noisy= [-2.35359548]
# fwd_noisy= [4.05520699]
# turn_noisy= [5.76761652]
# fwd_noisy= [4.78194486]
# turn_noisy= [0.67375627]
# fwd_noisy= [5.02858673]
# turn_noisy= [-3.48634613]
# fwd_noisy= [5.0872175]
# turn_noisy= [-8.68281199]
# fwd_noisy= [4.81943879]
# turn_noisy= [0.86001124]
# fwd_noisy= [5.02657965]
# turn_noisy= [-4.54613659]
# fwd_noisy= [5.06878995]
# turn_noisy= [6.25120985]
# fwd_noisy= [5.43812157]
# turn_noisy= [-5.00491058]
# fwd_noisy= [5.79990046]
# turn_noisy= [-0.39090517]
# fwd_noisy= [5.15950024]
# turn_noisy= [-2.87212144]
# fwd_noisy= [4.85967129]
# turn_noisy= [2.95845402]
# fwd_noisy= [5.32303062]
# turn_noisy= [-2.50302281]
# fwd_noisy= [6.33757817]
# turn_noisy= [3.30083882]
# fwd_noisy= [5.04148376]
# turn_noisy= [-8.49393994]
# fwd_noisy= [5.36224982]
# turn_noisy= [7.37133053]
